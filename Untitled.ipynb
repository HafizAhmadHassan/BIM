# %% [markdown]
# # Introduction
#
# This is out introduction to the project
#
# >Following are our steps
#
# 1.  We have dicussions fastai
# 2. link for that is forums.fast.ai

# %% [markdown]
# ## Step 1 : Reading Image / Image Registeration
#
# > In thi image registeration we have used the Itk Library
#
# We first ..this ....

# %%
path = '1__intrasubject_T2-T2' # set a convenient variable to store the path containing the data
#!itksnap -g {path}/e1_T2.nii.gz -o {path}/e2_T2.nii.gz

import itk

fixed_image = itk.imread(f'{path}/e1_T2.nii.gz')
moving_image = itk.imread(f'{path}/e2_T2.nii.gz')

#registered_image, params = itk.elastix_registration_method(fixed_image, moving_image)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-91e5812c0735> in <module>
#       4 import itk
#       5
# ----> 6 fixed_image = itk.imread(f'{path}/e1_T2.nii.gz')
#       7 moving_image = itk.imread(f'{path}/e2_T2.nii.gz')
#       8
#
# /usr/local/anaconda3/lib/python3.8/site-packages/itk/support/extras.py in imread(filename, pixel_type, fallback_only, imageio)
#    1291         reader = template_reader_type[ImageType].New(**kwargs)
#    1292     else:
# -> 1293         reader = template_reader_type.New(**kwargs)
#    1294     reader.Update()
#    1295     return reader.GetOutput()
#
# /usr/local/anaconda3/lib/python3.8/site-packages/itk/support/template_class.py in New(self, *args, **kwargs)
#     659         cur = itk.auto_pipeline.current
#     660         if self.__name__ == "itk::ImageFileReader":
# --> 661             return self._NewImageReader(
# ...

# %% [markdown]
# ## Step 2 : Visualization of Data

# %%
import numpy as np

# %%
# !pwd
# Out:
# /Users/hassan

# %%
from PIL import Image
image = Image.open('Desktop/teddy.jpeg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x350>

# %% [markdown]
# ![Teddy](Desktop/teddy.jpeg)

# %% [markdown]
# <img src="Desktop/teddy.jpeg">

# %% [markdown]
# # Paperspace
